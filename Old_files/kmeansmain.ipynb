# %%
import pandas as pd
import numpy as np
from sklearn.cluster impy = np.array(train['Survived'])ort KMeans
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train = pd.read_csv("Documents/datam.csv")
test = pd.read_csv("Documents/data.csv")

# %%
print("***** Train_Set *****")
print(train.head())
print("\n")
print("***** Test_Set *****")
print(test.head())
# Out:
# ***** Train_Set *****
#    Day  No Of Sessions  Accumulated Sessions  Unique Drivers  No. of Ports  \
# 0    1             1.0                     1               1            16
# 1    2             2.0                     3               1            16
# 2    3             3.0                     6               3            18
# 3    4             6.0                    12               6            20
# 4    5             2.0                    14               2            20
#
#    Energy(kWh)  Accumulated_Energy(MWh)  GHG_savings(kg)  \
# 0            7                     0.01              3.0
# 1           18                     0.02              7.0
# 2           11                     0.04              5.0
# 3           50                     0.09             21.0
# 4            3                     0.09              1.0
#
#    Accumulated GHG (kg)  Charge time (minutes)  Gasoline_Savings(gallons)  \
# 0                     3                    123                       0.82
# 1                    10                     24                       0.31
# 2                    15                    376                       3.30
# 3                    36                    406                       3.59
# 4                    37                     62                       0.37
#
#    Charge Fee(in$)  Charge_Type  Charge_demand
# 0               12        False          False
# 1                6        False          False
# 2               13        False          False
# 3               25        False          False
# 4                0        False          False
#
#
# ***** Test_Set *****
#    Date  No Of Sessions  Accumulated Sessions  Unique Drivers  No. of Ports  \
# 0     1            21.0                2920.0              19            32
# 1     2            19.0                2939.0              14            32
# 2     3            24.0                2963.0              23            32
# 3     4            14.0                2977.0              14            32
# 4     5            14.0                2991.0              12            32
#
#    Energy(kWh)  Accumulated_Energy(MWh)  GHG_savings(kg)  \
# 0          159                    19.75               67
# 1           78                    19.83               33
# 2          183                    20.01               77
# 3          117                    20.13               49
# 4          121                    20.25               51
#
#    Accumulated GHG (kg)  Charge time (minutes)  Gasoline_Savings(gallons)  \
# 0                  8295                   2145                      22.29
# 1                  8328                   1062                       9.40
# 2                  8404                   2143                      22.91
# 3                  8454                    924                       9.28
# 4                  8504                   1851                      20.01
#
#    Charge Fee(in$)  Charge_Type  Charge_demand
# 0             99.0        False           True
# 1             99.0        False           True
# 2             99.0        False           True
# 3             25.0        False          False
# 4             91.0        False           True

# %%
print("***** Train_Set *****")
print(train.describe())
print("\n")
print("***** Test_Set *****")
print(test.describe())
# Out:
# ***** Train_Set *****
#               Day  No Of Sessions  Accumulated Sessions  Unique Drivers  \
# count  365.000000      364.000000            365.000000      365.000000
# mean   183.000000       18.813187           2858.849315       16.487671
# std    105.510663        8.705670           2069.940635        7.484635
# min      1.000000        1.000000              1.000000        1.000000
# 25%     92.000000       13.000000            927.000000       11.000000
# 50%    183.000000       18.000000           2691.000000       16.000000
# 75%    274.000000       24.000000           4531.000000       21.000000
# max    365.000000       55.000000           7546.000000       47.000000
#
#        No. of Ports  Energy(kWh)  Accumulated_Energy(MWh)  GHG_savings(kg)  \
# count    365.000000   365.000000               365.000000       364.000000
# mean      32.975342   130.621918                19.727589        55.184066
# std        5.130382    68.022900                14.469623        28.768319
# min       16.000000     3.000000                 0.010000         1.000000
# 25%       28.000000    87.000000                 6.270000        36.000000
# 50%       32.000000   121.000000                18.150000        51.000000
# 75%       38.000000   164.000000                30.910000        69.000000
# max       40.000000   457.000000                53.450000       192.000000
#
#        Accumulated GHG (kg)  Charge time (minutes)  Gasoline_Savings(gallons)  \
# count            365.000000             365.000000                 365.000000
# mean            8279.082192            1708.668493                  16.749929
# std             6063.330680             909.504002                   9.189897
# min                3.000000              24.000000                   0.310000
# 25%             2634.000000            1089.000000                  10.750000
# 50%             7622.000000            1539.000000                  15.660000
# 75%            12981.000000            2146.000000                  21.380000
# max            21765.000000            6609.000000                  65.230000
#
#        Charge Fee(in$)
# count       365.000000
# mean         72.358904
# std          36.902082
# min           0.000000
# 25%          55.000000
# 50%          92.000000
# 75%          96.000000
# max          99.000000
#
#
# ***** Test_Set *****
#             Date  No Of Sessions  Accumulated Sessions  Unique Drivers  \
# count  167.00000      166.000000            166.000000      167.000000
# mean    84.00000       23.506024           4544.403614       20.808383
# std     48.35287        8.259978           1209.887413        6.932492
# min      1.00000        6.000000           2734.000000        6.000000
# 25%     42.50000       17.000000           3481.000000       16.000000
# 50%     84.00000       22.000000           4399.500000       19.000000
# 75%    125.50000       28.000000           5447.250000       25.000000
# max    167.00000       55.000000           6855.000000       47.000000
#
#        No. of Ports  Energy(kWh)  Accumulated_Energy(MWh)  GHG_savings(kg)  \
# count    167.000000   167.000000               167.000000       167.000000
# mean      36.814371   166.251497                31.296886        69.814371
# std        2.987167    67.434191                 8.711068        28.338450
# min       32.000000    30.000000                18.440000        13.000000
# 25%       32.000000   119.000000                23.870000        50.000000
# 50%       38.000000   155.000000                29.940000        65.000000
# 75%       38.000000   205.000000                37.645000        86.000000
# max       40.000000   457.000000                48.120000       192.000000
#
#        Accumulated GHG (kg)  Charge time (minutes)  Gasoline_Savings(gallons)  \
# count            167.000000             167.000000                 167.000000
# mean           13144.568862            2201.814371                  21.108503
# std             3658.847383             923.230588                   8.801093
# min             7744.000000             621.000000                   4.620000
# 25%            10026.000000            1546.500000                  15.060000
# 50%            12575.000000            2032.000000                  20.040000
# 75%            15809.000000            2648.000000                  25.560000
# max            20210.000000            6609.000000                  65.230000
#
#        Charge Fee(in$)
# count       166.000000
# mean         78.006024
# std          35.376845
# min           0.000000
# 25%          91.000000
# 50%          93.000000
# 75%          96.000000
# max          99.000000

# %%
print(train.columns.values)
# Out:
# ['Day' 'No Of Sessions' 'Accumulated Sessions' 'Unique Drivers'
#  'No. of Ports' 'Energy(kWh)' 'Accumulated_Energy(MWh)' 'GHG_savings(kg)'
#  'Accumulated GHG (kg)' 'Charge time (minutes)'
#  'Gasoline_Savings(gallons)' 'Charge Fee(in$)' 'Charge_Type'
#  'Charge_demand']

# %%
train.isna().head()
# Out:
#      Day  No Of Sessions  Accumulated Sessions  Unique Drivers  No. of Ports  \
# 0  False           False                 False           False         False
# 1  False           False                 False           False         False
# 2  False           False                 False           False         False
# 3  False           False                 False           False         False
# 4  False           False                 False           False         False
#
#    Energy(kWh)  Accumulated_Energy(MWh)  GHG_savings(kg)  \
# 0        False                    False            False
# 1        False                    False            False
# 2        False                    False            False
# 3        False                    False            False
# 4        False                    False            False
#
#    Accumulated GHG (kg)  Charge time (minutes)  Gasoline_Savings(gallons)  \
# 0                 False                  False                      False
# 1                 False                  False                      False
# 2                 False                  False                      False
# 3                 False                  False                      False
# 4                 False                  False                      False
#
#    Charge Fee(in$)  Charge_Type  Charge_demand
# 0            False        False          False
# 1            False        False          False
# 2            False        False          False
# 3            False        False          False
# 4            False        False          False

# %%
print("*****In the train set*****")
print(train.isna().sum())
print("\n")
print("*****In the test set*****")
print(test.isna().sum())
# Out:
# *****In the train set*****
# Day                          0
# No Of Sessions               1
# Accumulated Sessions         0
# Unique Drivers               0
# No. of Ports                 0
# Energy(kWh)                  0
# Accumulated_Energy(MWh)      0
# GHG_savings(kg)              1
# Accumulated GHG (kg)         0
# Charge time (minutes)        0
# Gasoline_Savings(gallons)    0
# Charge Fee(in$)              0
# Charge_Type                  0
# Charge_demand                0
# dtype: int64
#
#
# *****In the test set*****
# Date                         0
# No Of Sessions               1
# Accumulated Sessions         1
# Unique Drivers               0
# No. of Ports                 0
# Energy(kWh)                  0
# Accumulated_Energy(MWh)      0
# GHG_savings(kg)              0
# Accumulated GHG (kg)         0
# Charge time (minutes)        0
# Gasoline_Savings(gallons)    0
# Charge Fee(in$)              1
# Charge_Type                  0
# Charge_demand                0
# dtype: int64

# %%
test.isna().head()
# Out:
#     Date  No Of Sessions  Accumulated Sessions  Unique Drivers  No. of Ports  \
# 0  False           False                 False           False         False
# 1  False           False                 False           False         False
# 2  False           False                 False           False         False
# 3  False           False                 False           False         False
# 4  False           False                 False           False         False
#
#    Energy(kWh)  Accumulated_Energy(MWh)  GHG_savings(kg)  \
# 0        False                    False            False
# 1        False                    False            False
# 2        False                    False            False
# 3        False                    False            False
# 4        False                    False            False
#
#    Accumulated GHG (kg)  Charge time (minutes)  Gasoline_Savings(gallons)  \
# 0                 False                  False                      False
# 1                 False                  False                      False
# 2                 False                  False                      False
# 3                 False                  False                      False
# 4                 False                  False                      False
#
#    Charge Fee(in$)  Charge_Type  Charge_demand
# 0            False        False          False
# 1            False        False          False
# 2            False        False          False
# 3            False        False          False
# 4            False        False          False

# %%
train = train.applymap(lambda Charge_Type: 1 if Charge_Type == True else Charge_Type)
train = train.applymap(lambda Charge_Type: 0 if Charge_Type == False else Charge_Type)

# %%
train.fillna(train.mean(), inplace=True)

# %%
print(train.isna().sum())
# Out:
# Day                          0
# No Of Sessions               0
# Accumulated Sessions         0
# Unique Drivers               0
# No. of Ports                 0
# Energy(kWh)                  0
# Accumulated_Energy(MWh)      0
# GHG_savings(kg)              0
# Accumulated GHG (kg)         0
# Charge time (minutes)        0
# Gasoline_Savings(gallons)    0
# Charge Fee(in$)              0
# Charge_Type                  0
# Charge_demand                0
# dtype: int64

# %%
train[["Charge Fee(in$)", "Charge time (minutes)"]].groupby(['Charge Fee(in$)'], as_index=False).mean().sort_values(by='Charge time (minutes)', ascending=False)
# Out:
#     Charge Fee(in$)  Charge time (minutes)
# 21               90            2223.000000
# 28               97            2215.250000
# 26               95            2197.333333
# 22               91            2126.720930
# 23               92            2097.702703
# 24               93            1967.666667
# 29               98            1950.625000
# 25               94            1724.071429
# 27               96            1691.705882
# 30               99            1619.774194
# 0                 0            1554.302326
# 20               89            1546.000000
# 15               57            1062.000000
# 9                23             996.000000
# 13               35             990.000000
# 19               85             966.000000
# 17               65             870.000000
# 18               70             786.000000
# 4                15             761.500000
# 16               60             728.600000
# 2                12             651.375000
# 14               55             650.000000
# 12               30             624.800000
# 3                13             613.800000
# 7                20             603.000000
# 10               25             491.636364
# 8                21             487.000000
# 6                19             484.000000
# 11               26             428.000000
# 5                17             290.000000
# 1                 6              24.000000

# %%
train[["Charge Fee(in$)", "Energy(kWh)"]].groupby(['Charge Fee(in$)'], as_index=False).mean().sort_values(by='Energy(kWh)', ascending=False)
# Out:
#     Charge Fee(in$)  Energy(kWh)
# 21               90   183.000000
# 28               97   162.300000
# 23               92   161.567568
# 22               91   156.813953
# 26               95   149.641026
# 29               98   149.500000
# 24               93   148.250000
# 27               96   137.941176
# 25               94   132.428571
# 0                 0   126.186047
# 30               99   123.193548
# 15               57   118.000000
# 17               65   108.000000
# 19               85   108.000000
# 9                23    96.000000
# 20               89    93.500000
# 6                19    84.000000
# 14               55    75.500000
# 2                12    71.625000
# 13               35    70.000000
# 18               70    60.000000
# 16               60    57.200000
# 4                15    56.625000
# 10               25    55.181818
# 12               30    47.800000
# 3                13    44.400000
# 8                21    40.500000
# 7                20    40.000000
# 11               26    36.000000
# 5                17    29.000000
# 1                 6    18.000000

# %%
g = sns.FacetGrid(train, col='Charge_Type')
g.map(plt.hist, 'Charge Fee(in$)', bins=20)

# %%
grid = sns.FacetGrid(train, col='Charge_Type', row='Charge_demand', height=2.5, aspect=1.6)
grid.map(plt.hist, 'Charge Fee(in$)',alpha=1, bins=10)
grid.add_legend();

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 14 columns):
# Day                          365 non-null int64
# No Of Sessions               365 non-null float64
# Accumulated Sessions         365 non-null int64
# Unique Drivers               365 non-null int64
# No. of Ports                 365 non-null int64
# Energy(kWh)                  365 non-null int64
# Accumulated_Energy(MWh)      365 non-null float64
# GHG_savings(kg)              365 non-null float64
# Accumulated GHG (kg)         365 non-null int64
# Charge time (minutes)        365 non-null int64
# Gasoline_Savings(gallons)    365 non-null float64
# Charge Fee(in$)              365 non-null int64
# Charge_Type                  365 non-null int64
# Charge_demand                365 non-null int64
# dtypes: float64(4), int64(10)
# memory usage: 40.0 KB

# %%
X = np.array(train.drop(['Charge_Type'], 1).astype(float))

# %%
y = np.array(train['Charge_Type'])

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 14 columns):
# Day                          365 non-null int64
# No Of Sessions               365 non-null float64
# Accumulated Sessions         365 non-null int64
# Unique Drivers               365 non-null int64
# No. of Ports                 365 non-null int64
# Energy(kWh)                  365 non-null int64
# Accumulated_Energy(MWh)      365 non-null float64
# GHG_savings(kg)              365 non-null float64
# Accumulated GHG (kg)         365 non-null int64
# Charge time (minutes)        365 non-null int64
# Gasoline_Savings(gallons)    365 non-null float64
# Charge Fee(in$)              365 non-null int64
# Charge_Type                  365 non-null int64
# Charge_demand                365 non-null int64
# dtypes: float64(4), int64(10)
# memory usage: 40.0 KB

# %%
kmeans = KMeans(n_clusters=2)

# %%
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
correct = 0
for i in range(len(X)):
    predict = np.array(X[i].astype(float))
    predict = predict_me.reshape(-1, len(predict_me))
    prediction = kmeans.predict(predict_me)
    if prediction[0] == y[i]:
        correct += 1

print(correct/len(X))
# Out:
# 0.33424657534246577

# %%
from sklearn.cluster import KMeans
from sklearn import metrics
import numpy as np
import matplotlib.pyplot as plt

x1 = np.array([3, 1, 1, 2, 1, 6, 6, 6, 5, 6, 7, 8, 9, 8, 9, 9, 8])
x2 = np.array([5, 4, 6, 6, 5, 8, 6, 7, 6, 7, 1, 2, 1, 2, 3, 2, 3])

plt.plot()
plt.xlim([0, 10])
plt.ylim([0, 10])
plt.title('Dataset')
plt.scatter(x1, x2)
plt.show()

# create new plot and data
plt.plot()
X = np.array(list(zip(x1, x2))).reshape(len(x1), 2)
colors = ['b', 'g', 'r']
markers = ['o', 'v', 's']

# KMeans algorithm 
K = 3
kmeans_model = KMeans(n_clusters=K).fit(X)

plt.plot()
for i, l in enumerate(kmeans_model.labels_):
    plt.plot(x1[i], x2[i], color=colors[l], marker=markers[l],ls='None')
    plt.xlim([0, 10])
    plt.ylim([0, 10])

plt.show()

# %%
from sklearn.cluster import KMeans
from sklearn import metrics
import numpy as np
import matplotlib.pyplot as plt

x1 = np.array([3, 1, 1, 2, 1, 6, 6, 6, 5, 6, 7, 8, 9, 8, 9, 9, 8])
x2 = np.array([5, 4, 6, 6, 5, 8, 6, 7, 6, 7, 1, 2, 1, 2, 3, 2, 3])

plt.plot()
plt.xlim([0, 10])
plt.ylim([0, 10])
plt.title('Dataset')
plt.scatter(x1, x2)
plt.show()

# create new plot and data
plt.plot()
X = np.array(list(zip(x1, x2))).reshape(len(x1), 2)
colors = ['b', 'g', 'r']
markers = ['o', 'v', 's']

# KMeans algorithm 
K = 3
kmeans_model = KMeans(n_clusters=K).fit(X)

plt.plot()
for i, l in enumerate(kmeans_model.labels_):
    plt.plot(x1[i], x2[i], color=colors[l], marker=markers[l],ls='None')
    plt.xlim([0, 10])
    plt.ylim([0, 10])

plt.show()
